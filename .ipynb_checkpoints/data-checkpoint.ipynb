# %%
import os
import pandas as pd
from sqlalchemy import create_engine
import altair as alt
import numpy as np
from dotenv import load_dotenv
import umap
import re
from sklearn.preprocessing import StandardScaler

print("All imports successful")
# Out:
# All imports successful

# %%
load_dotenv()

host = os.getenv("MYSQL_HOST", "localhost")
port = os.getenv("MYSQL_PORT", "3306")
user = os.getenv("MYSQL_USER","root")
password = os.getenv("MYSQL_PSWD","2316")
db = os.getenv("MYSQL_DB", "rxnorm")

engine = create_engine(
    f"mysql+pymysql://{user}:{password}@{host}:{port}/{db}?charset=utf8mb4"
)

# %%
from sqlalchemy import text

def Searchbar(term):
    # Use text() to safely wrap your query
    sql = text("SELECT * FROM RXNCONSO WHERE STR LIKE :term AND TTY = 'BN'")
    
    with engine.connect() as conn:
        # Pass the parameter as a dictionary
        result = pd.read_sql(sql, conn, params={'term': f'%{term}%'})
    return result

x = Searchbar("Excedrin")
list(x["STR"])
# Out:
# ['Excedrin',
#  'Excedrin PM',
#  'Excedrin Tension Headache',
#  'Excedrin Quick Tab',
#  'Excedrin Back & Body',
#  'Excedrin Mild Headache',
#  'Excedrin PM Triple Action']

# %%
def Fetch_Drug_Form(name):

    query1 = text("""
        SELECT RXCUI 
        FROM RXNCONSO 
        WHERE STR = :name AND TTY = 'BN'
    """)

    with engine.connect() as conn:
        result1 = pd.read_sql(query1, conn, params={"name": name})

    if result1.empty:
        return pd.DataFrame()

    drug_id = result1["RXCUI"].iloc[0]

    query2 = text("""
        SELECT DISTINCT
            r.RXCUI2 AS Drug_Form_ID, 
            r.RELA AS Relation, 
            c.STR AS Drug_Form
        FROM RXNCONSO c
        JOIN RXNREL r ON c.RXCUI = r.RXCUI2
        WHERE r.RXCUI1 = :drug_id 
          AND c.TTY = 'DP'
    """)

    with engine.connect() as conn:
        result = pd.read_sql(query2, conn, params={"drug_id": drug_id})

    # Create Product_Name first
    result["Product_Name"] = result["Drug_Form"].str.extract(r'\[(.*?)\]')
    result["Product_Name"] = result["Product_Name"].fillna(result["Drug_Form"])

    # Case-insensitive dedup
    result = (
        result.assign(Product_Name_lower=result["Product_Name"].str.lower())
              .drop_duplicates(subset="Product_Name_lower")
              .drop(columns="Product_Name_lower")
    )

    return result

Fetch_Drug_Form("Excedrin")
# Out:
#    Drug_Form_ID        Relation  \
# 0        209468  has_ingredient
# 1        209468  has_ingredient
# 2        209468  has_ingredient
# 3        209468  has_ingredient
# 4        209468  has_ingredient
# 6        209468  has_ingredient
# 7        209468  has_ingredient
# 8        209468  has_ingredient
# 9        209468  has_ingredient
# 10       209468  has_ingredient
# 11       209468  has_ingredient
# 12       209468  has_ingredient
#
#                                             Drug_Form  \
# 0   ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 1   ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 2   ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 3   ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 4   ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 6   ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 7   ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 8   ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# ...

# %%
def Show_Ingredients(ID):
    query = f"""
    SELECT r.RXCUI2 as Ingredient_ID,r.RELA as Relation,c.STR as Ingredient
    from RXNCONSO c
    JOIN RXNREL r
    ON c.RXCUI = r.RXCUI2
    WHERE r.RXCUI1 = "{ID}" and c.TTY = "SCDC"
    GROUP by Ingredient_ID,Relation,Ingredient;
    """
    result1 = pd.read_sql(query, engine)
    return result1

df = Show_Ingredients(209468)
ingredients = list(df["Ingredient_ID"])
df
# Out:
#   Ingredient_ID     Relation            Ingredient
# 0        315259  constitutes  acetaminophen 250 MG
# 1        317311  constitutes        caffeine 65 MG
# 2        335953  constitutes        aspirin 250 MG

# %%
def Dose_Form(ID):
    query = f"""
    SELECT r.RXCUI2 as Ingredient_ID,r.RELA as Relation,c.STR as Ingredient
    from RXNCONSO c
    JOIN RXNREL r
    ON c.RXCUI = r.RXCUI2
    WHERE r.RXCUI1 = "{ID}" and c.TTY = "DF"
    GROUP by Ingredient_ID,Relation,Ingredient;
    """
    result = pd.read_sql(query, engine)
    DF = result["Ingredient"][0]
    return DF
Dose_Form(209387)
# Out:
# 'Oral Tablet'

# %%
def get_generic(ID):
    query = f"""
    SELECT r.RXCUI2 as Ingredient_ID,c.STR as Ingredient
    from RXNCONSO c
    JOIN RXNREL r
    ON c.RXCUI = r.RXCUI2
    WHERE r.RXCUI1 = "{ID}" and c.TTY = "SCD"
    GROUP by Ingredient_ID,Ingredient;
    """
    res = pd.read_sql(query, engine)
    return res
    
get_generic(209387)
# Out:
#   Ingredient_ID                        Ingredient
# 0        313782  acetaminophen 325 MG Oral Tablet

# %%
def Exact_Drugs(Ing_lst,ID):
    s = ""
    for i,j in enumerate(Ing_lst):
        if i == (len(Ing_lst) - 1):
            s+="r1.RXCUI1 = "+j
        else:
            s+="r1.RXCUI1 = "+j+" or "
            
    query = f"""
    WITH base AS (
        SELECT r2.RXCUI as ID, r2.STR as DP, r1.RXCUI1 as Ingredient_ID
        FROM RXNREL r1
        JOIN RXNCONSO r2
        ON r1.RXCUI2 = r2.RXCUI
        WHERE ({s}) and r2.TTY = "DP"
    ),
    keys_all AS (
        SELECT ID
        FROM base
        GROUP by ID
        HAVING COUNT(DISTINCT Ingredient_ID) = {len(Ing_lst)}
    )
    SELECT b.ID,b.DP
    FROM base b
    JOIN keys_all k
    ON b.ID = k.ID
    WHERE b.Id != {ID}
    GROUP BY b.ID, b.DP
    """
    
    res = pd.read_sql(query, engine)
    
    lst = []
    drp = []
    for j,i in enumerate(res["DP"]): 
        if "[" in i:
            d = i.split("[")
            lst.append(d[-1][:-1])
        else:
            lst.append("Generic")
            drp.append(j)

    res["Product_Name"] = lst
    
    Product = []
    for j,i in enumerate(res["Product_Name"]):
        if i.lower() in Product:
            drp.append(j)
        else:
            Product.append(i.lower())
    res = res.drop(drp)
    res = res.reset_index(drop=True)
    return res
    
df = Exact_Drugs(ingredients,209468)
df
# Out:
#          ID                                                 DP  \
# 0    308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 1    308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 2    308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 3    308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 4    308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 5    308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 6    308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 7    308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 8    308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 9    308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 10   308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 11   308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# 12   308297  acetaminophen 250 mg / aspirin 250 mg / caffei...
# 13   308297  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / CAFFEI...
# ...

# %%
def Union_Drugs(Ing_lst,ID):
    s = ""
    for i,j in enumerate(Ing_lst):
        if i == (len(Ing_lst) - 1):
            s+="r1.RXCUI1 = "+j
        else:
            s+="r1.RXCUI1 = "+j+" or "
            
    query = f"""
    WITH base AS (
        SELECT r2.RXCUI as ID, r2.STR as DP, r1.RXCUI1 as Ingredient_ID
        FROM RXNREL r1
        JOIN RXNCONSO r2
        ON r1.RXCUI2 = r2.RXCUI
        WHERE ({s}) and r2.TTY = "DP"
    ),
    keys_all AS (
        SELECT ID
        FROM base
        GROUP by ID
        HAVING COUNT(DISTINCT Ingredient_ID) < {len(Ing_lst)}
    )
    SELECT b.ID,b.DP
    FROM base b
    JOIN keys_all k
    ON b.ID = k.ID
    WHERE b.Id != {ID}
    GROUP BY b.ID, b.DP
    """
    
    res = pd.read_sql(query, engine)
    
    lst = []
    drp = []
    for j,i in enumerate(res["DP"]): 
        if "[" in i:
            d = i.split("[")
            lst.append(d[-1][:-1])
        else:
            lst.append("Generic")
            drp.append(j)

    res["Product_Name"] = lst
    
    Product = []
    for j,i in enumerate(res["Product_Name"]):
        if i.lower() in Product:
            drp.append(j)
        else:
            Product.append(i.lower())
    res = res.drop(drp)
    res = res.drop_duplicates(subset="ID")
    res = res.reset_index(drop=True)
    return res
    
df = Union_Drugs(ingredients,209468)
df
# Out:
#          ID                                                 DP  \
# 0   1053327  CAFFEINE 65 mg / ASPIRIN 845 mg ORAL POWDER [S...
# 1   1536477  ACETAMINOPHEN 250 mg in 250 / CHLORPHENIRAMINE...
# 2    404172  ACETAMINOPHEN 500 mg / CAFFEINE 65 mg ORAL TAB...
# 3   2360605  ASPIRIN 500 mg / ACETAMINOPHEN 500 mg / CAFFEI...
# 4   1432488  PHENYLEPHRINE HYDROCHLORIDE 5 mg / ACETAMINOPH...
# 5   1247402  ASPIRIN 845 mg / CAFFEINE 65 mg ORAL POWDER [B...
# 6    307686  ACETAMINOPHEN 500 mg / CAFFEINE 65 mg ORAL TAB...
# 7   2387532  ACETAMINOPHEN 250 mg / IBUPROFEN 125 mg ORAL T...
# 8   1593110  ACETAMINOPHEN 250 mg / ASPIRIN 250 mg / DIPHEN...
# 9    692836  CAFFEINE 65 mg / ACETAMINOPHEN 325 mg / ASPIRI...
# 10  1536815  CAFFEINE 65 mg / ASPIRIN 500 mg ORAL TABLET, E...
# 11  2626726  CAFFEINE 65 mg / ASPIRIN 650 mg ORAL POWDER [B...
# 12  1872075  ACETAMINOPHEN 500 mg / CAFFEINE 65 mg ORAL TAB...
# 13   994435  CAFFEINE 65 mg / ASPIRIN 845 mg ORAL POWDER [K...
# ...

# %%
def Fetch_Ingredients(ID):
    query = f"""
    SELECT c.STR as Full_String
    FROM RXNCONSO c
    JOIN RXNREL r
        ON c.RXCUI = r.RXCUI2
    WHERE r.RXCUI1 = "{ID}"
      AND c.TTY = "SCDC"
    GROUP BY Full_String;
    """

    df = pd.read_sql(query, engine)

    results = []

    for text in df["Full_String"]:
        match = re.match(r"(.+?)\s+(\d+)\s+MG", text)
        if match:
            ingredient = match.group(1)
            concentration = float(match.group(2))
            results.append({
                "Ingredient": ingredient,
                "Concentration": concentration
            })

    return results

# %%
def Fetch_Heatmap(df, drug_of_interest_id, drug_of_interest_name):

    # Add searched drug
    searched_row = pd.DataFrame({
        "ID": [drug_of_interest_id],
        "Product_Name": [drug_of_interest_name]
    })

    df_extended = pd.concat([searched_row, df], ignore_index=True)

    # Build long-format table
    rows = []

    for _, row in df_extended.iterrows():
        ingredients = Fetch_Ingredients(row["ID"])

        for ing in ingredients:
            rows.append({
                "Product_Name": row["Product_Name"],
                "Ingredient": ing["Ingredient"],
                "Concentration": ing["Concentration"]
            })

    long_df = pd.DataFrame(rows)

    # Create heatmap matrix
    heatmap_df = long_df.pivot_table(
        index="Product_Name",
        columns="Ingredient",
        values="Concentration",
        fill_value=0
    ).reset_index()

    # NEW PART: create ingredients list column
    ingredient_list_df = (
        long_df.groupby("Product_Name")["Ingredient"]
        .apply(list)
        .reset_index(name="Ingredients_List")
    )

    # Merge into heatmap_df
    heatmap_df = heatmap_df.merge(
        ingredient_list_df,
        on="Product_Name",
        how="left"
    )

    return heatmap_df

# %%
heatmap_df = Fetch_Heatmap(df,209468,"Excedrin")
heatmap_df
# Out:
#                                          Product_Name  acetaminophen  aspirin  \
# 0                        Aacetaminophen and Ibuprofen          250.0      0.0
# 1                        Alka-Seltzer Hangover Relief            0.0    500.0
# 2   Alka-Seltzer Plus Severe Cough Mucus and Conge...          250.0      0.0
# 3                                        BC Arthritis            0.0   1000.0
# 4                                           BC Cherry            0.0    845.0
# 5                                              BC MAX          500.0    500.0
# 6                        Bayer Rapid Relief Body Pain            0.0    650.0
# 7     Defensol D (Multi Symptom Effervescent Tablets)          250.0      0.0
# 8                                            Excedrin          250.0    250.0
# 9                   Excedrin PM Triple Action Caplets          250.0    250.0
# 10                          Excedrin Tension Headache          500.0      0.0
# ...

# %%
import altair as alt
import pandas as pd

def Create_Altair_Heatmap(heatmap_df, drug_of_interest_name):
    if "Product_Name" not in heatmap_df.columns:
        heatmap_df = heatmap_df.reset_index()

    # Height based on number of products
    num_products = heatmap_df["Product_Name"].nunique()
    height_per_product = 14
    dynamic_height = max(250, min(1400, num_products * height_per_product))

    # Melt only ingredient columns
    non_ingredient_cols = {"Product_Name", "Ingredients_List", "ID"}
    value_cols = [c for c in heatmap_df.columns if c not in non_ingredient_cols]

    df_long = heatmap_df.melt(
        id_vars=["Product_Name"],
        value_vars=value_cols,
        var_name="Ingredient",
        value_name="Concentration"
    )

    df_long["Product_Name"] = df_long["Product_Name"].astype(str)
    df_long["Ingredient"] = df_long["Ingredient"].astype(str)
    df_long["Concentration"] = pd.to_numeric(df_long["Concentration"], errors="coerce").fillna(0)

    # Relative concentration per ingredient
    df_long["Relative_Conc"] = (
        df_long.groupby("Ingredient")["Concentration"]
        .transform(lambda x: x / x.max() if x.max() != 0 else 0)
    )

    # ---- zebra banding dataset ----
    # Use the ingredient domain to create "span" from first to last ingredient
    ingredients = sorted(df_long["Ingredient"].unique())
    if len(ingredients) == 0:
        return alt.Chart(pd.DataFrame({"msg": ["No data to plot."]})).mark_text().encode(text="msg:N")

    first_ing = ingredients[0]
    last_ing = ingredients[-1]

    df_rows = (
        df_long[["Product_Name"]]
        .drop_duplicates()
        .sort_values("Product_Name")  # change ordering here if you want
        .reset_index(drop=True)
    )
    df_rows["row_index"] = df_rows.index
    df_rows["is_odd"] = (df_rows["row_index"] % 2 == 1)
    df_rows["x_start"] = first_ing
    df_rows["x_end"] = last_ing

    # Shared encodings
    base = alt.Chart(df_long).encode(
    x=alt.X(
        "Ingredient:N",
        axis=alt.Axis(labelAngle=-45),
        sort=ingredients,
        scale=alt.Scale(padding=0)   # IMPORTANT FIX
    ),
    y=alt.Y("Product_Name:N", sort='-x')
)

    # 0) Zebra row bands (full width from first ingredient to last ingredient)
    row_bands = alt.Chart(df_rows).mark_rect().encode(
    x=alt.X(
        "x_start:N",
        sort=ingredients,
        scale=alt.Scale(padding=0),   # removes left/right padding
        title=None
    ),
    x2="x_end:N",
    y=alt.Y("Product_Name:N", sort='-x'),
    color=alt.condition(
        alt.datum.is_odd,
        alt.value("#efe7f6"),
        alt.value("#f6f3ef")
    )
)
    # 1) Highlight zero cells ONLY for drug_of_interest row
    highlight_zeros = base.transform_filter(
        (alt.datum.Product_Name == str(drug_of_interest_name)) &
        (alt.datum.Concentration == 0)
    ).mark_rect().encode(
        color=alt.value("#f3d7d7")
    )

    # 2) Main heatmap: non-zero cells only
    nonzero_layer = base.transform_filter(
        alt.datum.Concentration > 0
    ).mark_rect().encode(
        color=alt.Color(
            "Relative_Conc:Q",
            scale=alt.Scale(scheme="reds", domain=[0, 1]),
            title="Relative Concentration"
        ),
        tooltip=[
            "Product_Name:N",
            "Ingredient:N",
            alt.Tooltip("Concentration:Q", title="Concentration (mg)"),
            alt.Tooltip("Relative_Conc:Q", format=".2f", title="Relative")
        ]
    )

    chart = (row_bands + highlight_zeros + nonzero_layer).properties(
        width=700,
        height=dynamic_height,
        title=f"Ingredient Concentration Heatmap (zebra rows + 0-cells highlighted for: {drug_of_interest_name})"
    ).configure_view(
        fill="#f6f3ef",
        strokeOpacity=0
    ).configure(
        background="#f6f3ef"
    )

    return chart

# %%
Create_Altair_Heatmap(heatmap_df,"Excedrin")
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Clustering

# %%
import pandas as pd
import altair as alt
from sklearn.preprocessing import StandardScaler
import umap

def Clustering(
    df,
    product_col="Product_Name",
    highlight_products=None,
    non_ingredient_cols=("ID",),   # add any non-ingredient columns here
    width=650,
    height=450,
    point_size=110,
    scale=True,
    n_neighbors=15,
    min_dist=0.1,
    metric="euclidean",
    random_state=42,
    ingredients_newline=True
):
    # --- 1) Build feature matrix with ONLY ingredient columns ---
    df2 = df.copy()

    # Drop known non-ingredient columns if they exist
    drop_cols = [c for c in non_ingredient_cols if c in df2.columns]
    if drop_cols:
        df2 = df2.drop(columns=drop_cols)

    # Set product as index
    X = df2.set_index(product_col)

    # Make sure all ingredient columns are numeric
    X = X.apply(pd.to_numeric, errors="coerce").fillna(0)

    # --- 2) Build ingredient list per product ---
    joiner = "\n" if ingredients_newline else ", "
    ingredients_series = X.apply(
        lambda row: joiner.join(row.index[row.to_numpy() > 0]),
        axis=1
    )

    # If you want to see whether it's working:
    # print(ingredients_series.head())

    # --- 3) Scale ---
    X_emb = StandardScaler().fit_transform(X) if scale else X.to_numpy()

    # --- 4) UMAP ---
    reducer = umap.UMAP(
        n_components=2,
        n_neighbors=n_neighbors,
        min_dist=min_dist,
        metric=metric,
        random_state=random_state
    )
    coords = reducer.fit_transform(X_emb)

    # --- 5) Embedding dataframe ---
    emb_df = pd.DataFrame(coords, columns=["Dim1", "Dim2"], index=X.index).reset_index()
    emb_df = emb_df.rename(columns={"index": product_col})
    emb_df["Ingredients"] = ingredients_series.values

    # --- 6) Case-insensitive highlight ---
    if highlight_products is None:
        emb_df["Highlight"] = "Other"
    else:
        if isinstance(highlight_products, str):
            highlight_products = [highlight_products]
        highlight_set = {p.upper() for p in highlight_products}
        emb_df["Highlight"] = emb_df[product_col].str.upper().apply(
            lambda x: "Core Product" if x in highlight_set else "Other"
        )

    # --- 7) Plot ---
    chart = (
        alt.Chart(emb_df)
        .mark_circle(size=point_size)
        .encode(
            x=alt.X("Dim1:Q", title="UMAP 1"),
            y=alt.Y("Dim2:Q", title="UMAP 2"),
            color=alt.Color(
                "Highlight:N",
                scale=alt.Scale(domain=["Core Product", "Other"], range=["red", "lightgray"]),
                legend=alt.Legend(title="Product Type")
            ),
            tooltip=[
                alt.Tooltip(product_col, title="Product"),
                alt.Tooltip("Ingredients:O", title="Ingredients")  # <-- IMPORTANT
            ]
        )
        .properties(width=width, height=height, title="Product Similarity Scatter (UMAP)")
        .interactive()
    )

    return chart, emb_df

# %%
chart, emb = Clustering(df, highlight_products="Tylenol PM")
chart
# Out:
# C:\Users\ckart\miniconda3\envs\dsenv\Lib\site-packages\umap\umap_.py:1952: UserWarning: n_jobs value 1 overridden to 1 by setting random_state. Use no seed for parallelism.
#   warn(
# alt.Chart(...)
